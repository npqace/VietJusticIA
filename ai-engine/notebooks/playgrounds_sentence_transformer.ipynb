# %%
! pip install langchain_community tiktoken langchain_text_splitters faiss-cpu qdrant-client protonx dotenv langchain-google-genai pyvi rank_bm25 numpy sentence-transformers ipywidgets

# %% [markdown]
# # I. Setup

# %%
import os
import json
import sys
import time
import re
from typing import List

import tiktoken
from dotenv import load_dotenv
from langchain.retrievers import EnsembleRetriever
from langchain.storage import InMemoryStore
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_community.retrievers import BM25Retriever
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
from langchain_core.embeddings import Embeddings
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_google_genai import ChatGoogleGenerativeAI
from protonx import ProtonX
from pyvi import ViTokenizer
from tqdm import tqdm

from IPython.display import Markdown, display

load_dotenv()
# Out:
# True

# %%
! langchain -v
# Out:
# langchain-cli 0.0.37

# %% [markdown]
# # II. Load Documents

# %%
# Enhanced document loading with metadata preservation - TESTING VERSION (50 docs only)

def load_legal_docs_from_folders(root_dir: str, max_docs: int = 50) -> list[Document]:
    """
    Enhanced loader that preserves structured metadata from folders containing
    both 'metadata.json' and 'content.txt' files.

    Args:
        root_dir: Directory to load documents from
        max_docs: Maximum number of documents to load (for testing)
    """
    documents = []
    doc_count = 0

    print(f"\n[INFO] Starting enhanced loading from '{root_dir}'...")

    for dirpath, _, filenames in os.walk(root_dir):
        if doc_count >= max_docs:
            break

        if "metadata.json" in filenames and "content.txt" in filenames:
            metadata_path = os.path.join(dirpath, "metadata.json")
            content_path = os.path.join(dirpath, "content.txt")

            try:
                with open(metadata_path, 'r', encoding='utf-8') as f:
                    metadata_json = json.load(f)
                with open(content_path, 'r', encoding='utf-8') as f:
                    full_text = f.read()

                # Enhanced page content with title
                page_content = (
                    f"Tiêu đề: {metadata_json.get('title', '')}\n\n"
                    f"Toàn văn: {full_text}"
                )

                # Extract specific metadata fields from the diagram section
                id_metadata = metadata_json.get("metadata", {})
                diagram_metadata = metadata_json.get("metadata", {}).get("diagram", {})

                # Create final metadata with only the required fields
                final_metadata = {
                    '_id': id_metadata.get('_id', ''),
                    'so_hieu': diagram_metadata.get('so_hieu', ''),
                    'loai_van_ban': diagram_metadata.get('loai_van_ban', ''),
                    'linh_vuc_nganh': diagram_metadata.get('linh_vuc_nganh', ''),
                    'noi_ban_hanh': diagram_metadata.get('noi_ban_hanh', ''),
                    'nguoi_ky': diagram_metadata.get('nguoi_ky', ''),
                    'ngay_ban_hanh': diagram_metadata.get('ngay_ban_hanh', ''),
                    'ngay_hieu_luc': diagram_metadata.get('ngay_hieu_luc', ''),
                    'tinh_trang': diagram_metadata.get('tinh_trang', ''),
                    'title': metadata_json.get('title', ''),
                    'source': content_path,
                    'doc_id': doc_count + 1  # Add document ID for testing
                }

                doc = Document(page_content=page_content, metadata=final_metadata)
                documents.append(doc)
                doc_count += 1

                # Dynamic progress indicator
                progress_message = f"  -> Progress: {doc_count}/{max_docs} documents loaded."
                sys.stdout.write('\r' + progress_message)
                sys.stdout.flush()

            except Exception as e:
                # Print error on a new line to avoid being overwritten by progress
                print(f"\n[ERROR] Failed to process document in {dirpath}: {e}")

    # Print a newline to move past the progress indicator line
    print()
    return documents

# --- SCRIPT EXECUTION ---

# TESTING CONFIGURATION - Load only a few documents
root_dir = '../data/raw_data/documents'
MAX_DOCS_FOR_TESTING = 500

print("=" * 70)
print("   STARTING DOCUMENT LOADING SCRIPT (TESTING MODE)")
print(f"[INFO] Source Directory: {root_dir}")
print(f"[INFO] Document Limit: {MAX_DOCS_FOR_TESTING}")
print("=" * 70)

try:
    docs = load_legal_docs_from_folders(root_dir, max_docs=MAX_DOCS_FOR_TESTING)
    print(f"[SUCCESS] Enhanced loading complete. Found {len(docs)} structured documents.")
    if docs:
        print("\n[DEBUG] Sample metadata from the first document:")
        # Pretty print the JSON metadata for readability
        print(json.dumps(docs[0].metadata, indent=2, ensure_ascii=False))

except Exception as e:
    print(f"\n[ERROR] Enhanced loading process failed: {e}")
    print("[INFO] Attempting fallback to simple directory loading...")

    try:
        # Fallback to simple loading with limit
        loader = DirectoryLoader(
            root_dir,
            glob='**/*.txt',
            loader_cls=TextLoader,
            show_progress=True # Langchain's built-in progress bar
        )
        all_docs = loader.load()
        docs = all_docs[:MAX_DOCS_FOR_TESTING]
        print(f'[SUCCESS] Simple loading complete. Loaded {len(docs)} documents (capped at {MAX_DOCS_FOR_TESTING}).')
    except Exception as fallback_e:
        print(f"[ERROR] Fallback loading also failed: {fallback_e}")
        docs = [] # Ensure docs is an empty list on total failure

print("\n" + "=" * 70)
print("   FINAL SUMMARY")
if docs:
    print(f"  -> Total documents loaded: {len(docs)}")
    print("  -> Status: Ready for next processing steps.")
    print("\nPreview of first document content:")
    print("-" * 40)
    print(f"{docs[0].page_content[:300]}...")
    print("-" * 40)
else:
    print("  -> No documents were loaded. Please check the source directory and error logs.")
print("=" * 70)
# Out:
# ======================================================================
#    STARTING DOCUMENT LOADING SCRIPT (TESTING MODE)
# [INFO] Source Directory: ../data/raw_data/documents
# [INFO] Document Limit: 500
# ======================================================================
#
# [INFO] Starting enhanced loading from '../data/raw_data/documents'...
#   -> Progress: 500/500 documents loaded.
# [SUCCESS] Enhanced loading complete. Found 500 structured documents.
#
# [DEBUG] Sample metadata from the first document:
# {
#   "_id": "66b9c0963ab9c4ae3d5fb5b4",
#   "so_hieu": "02/CT-UBND",
#   "loai_van_ban": "Chỉ thị",
#   "linh_vuc_nganh": "Giáo dục",
#   "noi_ban_hanh": "Tỉnh Bắc Kạn",
#   "nguoi_ky": "Phạm Duy Hưng",
#   "ngay_ban_hanh": "24/05/2024",
#   "ngay_hieu_luc": "24/05/2024",
#   "tinh_trang": "Còn hiệu lực",
#   "title": "Chỉ thị 02/CT-UBND tăng cường chỉ đạo, phối hợp tổ chức Kỳ thi tốt nghiệp trung học phổ thông và tuyển sinh đại học, cao đẳng năm 2024 do tỉnh Bắc Kạn ban hành",
#   "source": "../data/raw_data/documents\\Chỉ thị 02CT-UBND tăng cường chỉ đạo, phối hợp tổ chức Kỳ thi tốt nghiệp trung học phổ thông và tuyể\\content.txt",
#   "doc_id": 1
# }
#
# ======================================================================
#    FINAL SUMMARY
#   -> Total documents loaded: 500
#   -> Status: Ready for next processing steps.
#
# Preview of first document content:
# ----------------------------------------
# Tiêu đề: Chỉ thị 02/CT-UBND tăng cường chỉ đạo, phối hợp tổ chức Kỳ thi tốt nghiệp trung học phổ thông và tuyển sinh đại học, cao đẳng năm 2024 do tỉnh Bắc Kạn ban hành
#
# Toàn văn: ỦY BAN NHÂN DÂN  TỈNH BẮC KẠN  ------- CỘNG HÒA XÃ HỘI  CHỦ NGHĨA VIỆT NAM  Độc lập - Tự do - Hạnh phúc ---------------
# ...
# ----------------------------------------
# ======================================================================

# %% [markdown]
# # III. Document Splitting (Parent-Child Architecture)

# %%
# Enhanced Intelligent Chunking for Legal Documents
tokenizer = tiktoken.get_encoding("cl100k_base")

# create the length function
def tiktoken_len(text):
    tokens = tokenizer.encode(
        text,
        disallowed_special=()
    )
    return len(tokens)

# %%
class IntelligentLegalChunker:
    """
    Advanced chunking strategy for legal documents that:
    1. Respects token limits (max 3500 tokens to stay under 4096 limit)
    2. Preserves paragraph boundaries
    3. Handles oversized paragraphs intelligently
    4. Maintains context between chunks
    """

    def __init__(self, max_tokens=3500, overlap_tokens=200):
        self.max_tokens = max_tokens
        self.overlap_tokens = overlap_tokens
        self.tokenizer = tokenizer

    def split_paragraph_intelligently(self, paragraph, max_tokens=None):
        """Split a single paragraph that's too large"""
        if max_tokens is None:
            max_tokens = self.max_tokens

        # Try to split on sentences first
        sentences = re.split(r'(?<=[.!?])\s+', paragraph)
        if len(sentences) <= 1:
            # If no sentence breaks, split on words
            words = paragraph.split()
            chunks = []
            current_chunk = []
            current_tokens = 0

            for word in words:
                word_tokens = self.tokenizer.encode(word, disallowed_special=())
                if current_tokens + len(word_tokens) > max_tokens and current_chunk:
                    chunks.append(' '.join(current_chunk))
                    current_chunk = [word]
                    current_tokens = len(word_tokens)
                else:
                    current_chunk.append(word)
                    current_tokens += len(word_tokens)

            if current_chunk:
                chunks.append(' '.join(current_chunk))
            return chunks

        # Split by sentences
        chunks = []
        current_chunk = []
        current_tokens = 0

        for sentence in sentences:
            sentence_tokens = self.tokenizer.encode(sentence, disallowed_special=())
            if current_tokens + len(sentence_tokens) > max_tokens and current_chunk:
                chunks.append(' '.join(current_chunk))
                current_chunk = [sentence]
                current_tokens = len(sentence_tokens)
            else:
                current_chunk.append(sentence)
                current_tokens += len(sentence_tokens)

        if current_chunk:
            chunks.append(' '.join(current_chunk))
        return chunks

    def chunk_document(self, document):
        """Chunk a document intelligently"""
        content = document.page_content
        metadata = document.metadata.copy()

        # Split by double newlines (paragraphs)
        paragraphs = content.split('\n\n')
        chunks = []
        current_chunk = []
        current_tokens = 0

        for paragraph in paragraphs:
            paragraph = paragraph.strip()
            if not paragraph:
                continue

            paragraph_tokens = self.tokenizer.encode(paragraph, disallowed_special=())

            # If single paragraph is too large, split it
            if len(paragraph_tokens) > self.max_tokens:
                # Add current chunk if it exists
                if current_chunk:
                    chunks.append('\n\n'.join(current_chunk))
                    current_chunk = []
                    current_tokens = 0

                # Split the oversized paragraph
                sub_chunks = self.split_paragraph_intelligently(paragraph)
                for sub_chunk in sub_chunks:
                    chunks.append(sub_chunk)
                continue

            # Check if adding this paragraph would exceed limit
            if current_tokens + len(paragraph_tokens) > self.max_tokens and current_chunk:
                # Save current chunk
                chunks.append('\n\n'.join(current_chunk))

                # Start new chunk with overlap if possible
                if len(current_chunk) > 0:
                    # Try to include last paragraph for overlap
                    overlap_text = current_chunk[-1]
                    overlap_tokens = self.tokenizer.encode(overlap_text, disallowed_special=())
                    if len(overlap_tokens) <= self.overlap_tokens:
                        current_chunk = [overlap_text, paragraph]
                        current_tokens = len(overlap_tokens) + len(paragraph_tokens)
                    else:
                        current_chunk = [paragraph]
                        current_tokens = len(paragraph_tokens)
                else:
                    current_chunk = [paragraph]
                    current_tokens = len(paragraph_tokens)
            else:
                current_chunk.append(paragraph)
                current_tokens += len(paragraph_tokens)

        # Add final chunk
        if current_chunk:
            chunks.append('\n\n'.join(current_chunk))

        # Create Document objects for each chunk
        chunk_docs = []
        for i, chunk_content in enumerate(chunks):
            chunk_metadata = metadata.copy()
            chunk_metadata['chunk_id'] = i
            chunk_metadata['total_chunks'] = len(chunks)
            chunk_docs.append(Document(page_content=chunk_content, metadata=chunk_metadata))

        return chunk_docs

print("Intelligent Legal Chunker initialized successfully!")
print("Features:")
print("- Respects 3500 token limit (safe for 4096 API limit)")
print("- Preserves paragraph boundaries")
print("- Handles oversized paragraphs intelligently")
print("- Maintains context with smart overlap")
# Out:
# Intelligent Legal Chunker initialized successfully!
# Features:
# - Respects 3500 token limit (safe for 4096 API limit)
# - Preserves paragraph boundaries
# - Handles oversized paragraphs intelligently
# - Maintains context with smart overlap

# %%
# Enhanced Parent-Child Architecture with Intelligent Chunking
print("Setting up enhanced parent-child document architecture with intelligent chunking...")

# Initialize the intelligent chunker
intelligent_chunker = IntelligentLegalChunker(max_tokens=3500, overlap_tokens=200)

# Create parent chunks and store them
docstore = InMemoryStore()
child_chunks = []

print(f"Processing {len(docs)} documents with intelligent chunking...")

for doc_idx, doc in enumerate(docs):
    print(f"Processing document {doc_idx + 1}/{len(docs)}: {doc.metadata.get('title', 'Unknown')[:50]}...")

    # Use intelligent chunking for parent chunks
    parent_chunks = intelligent_chunker.chunk_document(doc)

    for i, parent_chunk in enumerate(parent_chunks):
        parent_id = f"{doc.metadata.get('title', 'doc')}-{i}"
        docstore.mset([(parent_id, parent_chunk)])

        # For child chunks, use smaller intelligent chunking
        child_chunker = IntelligentLegalChunker(max_tokens=800, overlap_tokens=100)
        sub_chunks = child_chunker.chunk_document(parent_chunk)

        for sub_chunk in sub_chunks:
            sub_chunk.metadata['parent_id'] = parent_id
            # Preserve original metadata
            sub_chunk.metadata.update(doc.metadata)
            child_chunks.append(sub_chunk)

print(f"[INFO] Created {len(child_chunks)} child chunks from {len(docs)} documents.")
print(f"[INFO] Parent chunks stored in docstore for context retrieval.")

# Verify chunk sizes
chunk_sizes = [tiktoken_len(chunk.page_content) for chunk in child_chunks]
print(f"[INFO] Chunk size statistics:")
print(f"   - Min tokens: {min(chunk_sizes)}")
print(f"   - Max tokens: {max(chunk_sizes)}")
print(f"   - Avg tokens: {sum(chunk_sizes)//len(chunk_sizes)}")
print(f"   - Chunks over 3500 tokens: {sum(1 for size in chunk_sizes if size > 3500)}")

if max(chunk_sizes) > 3500:
    print(f"[WARNING] Some chunks still exceed 3500 tokens.")
    print("   This might cause API errors. Consider reducing max_tokens further.")
else:
    print("[SUCCESS] All chunks are within safe token limits.")
# Out:
# Setting up enhanced parent-child document architecture with intelligent chunking...
# Processing 500 documents with intelligent chunking...
# Processing document 1/500: Chỉ thị 02/CT-UBND tăng cường chỉ đạo, phối hợp tổ...
# Processing document 2/500: Chỉ thị 03/CT-CTUBND tổ chức Kỳ thi tốt nghiệp tru...
# Processing document 3/500: Chỉ thị 03/CT-UBND năm 2024 tăng cường công tác ...
# Processing document 4/500: Chỉ thị 03/CT-UBND tăng cường phối hợp tổ chức Kỳ ...
# Processing document 5/500: Chỉ thị 03/CT-UBND tổ chức Kỳ thi tốt nghiệp trung...
# Processing document 6/500: Chỉ thị 04/CT-UBND tăng cường chỉ đạo, phối hợp tổ...
# Processing document 7/500: Chỉ thị 04/CT-UBND về chỉ đạo, phối hợp tổ chức kỳ...
# Processing document 8/500: Chỉ thị 04/CT-UBND về tăng cường chỉ đạo, phối hợp...
# Processing document 9/500: Chỉ thị 04/CT-UBND về tăng cường chỉ đạo, phối hợp...
# Processing document 10/500: Chỉ thị 04/CT-UBND về tổ chức các kỳ thi trên địa ...
# Processing document 11/500: Chỉ thị 05/CT-UBND năm 2024 về tăng cường chỉ đạo,...
# Processing document 12/500: Chỉ thị 05/CT-UBND về tăng cường chỉ đạo, phối hợp...
# Processing document 13/500: Chỉ thị 05/CT-UBND về tổ chức kỳ thi tốt nghiệp tr...
# Processing document 14/500: Chỉ thị 05/CT-UBND về tổ chức kỳ thi tốt nghiệp tr...
# Processing document 15/500: Chỉ thị 06/CT-UBND về tăng cường chỉ đạo, phối hợp...
# Processing document 16/500: Chỉ thị 06/CT-UBND về tăng cường chỉ đạo, phối hợp...
# Processing document 17/500: Chỉ thị 06/CT-UBND về tăng cường công tác phối hợp...
# Processing document 18/500: Chỉ thị 07/CT-UBND về tăng cường chỉ đạo tổ chức K...
# Processing document 19/500: Chỉ thị 07/CT-UBND về tăng cường chỉ đạo, phối hợp...
# Processing document 20/500: Chỉ thị 07/CT-UBND về tăng cường phối hợp tổ chức ...
# Processing document 21/500: Chỉ thị 08/CT-UBND tăng cường chỉ đạo công tác tổ ...
# Processing document 22/500: Chỉ thị 09/CT-UBND về tăng cường chỉ đạo, phối hợp...
# Processing document 23/500: Chỉ thị 10/CT-UBND năm 2024 tăng cường công tác qu...
# Processing document 24/500: Chỉ thị 10/CT-UBND tổ chức các kỳ thi trên địa bàn...
# Processing document 25/500: Chỉ thị 11/CT-UBND về công tác tổ chức Kỳ thi tốt ...
# Processing document 26/500: Chỉ thị 12/CT-UBND về tăng cường chỉ đạo, phối hợp...
# Processing document 27/500: Chỉ thị 13/CT-UBND về tổ chức Kỳ thi tốt nghiệp tr...
# Processing document 28/500: Chỉ thị 13/CT-UBND về tổ chức Kỳ thi tốt nghiệp tr...
# Processing document 29/500: Chỉ thị 14/CT-UBND về chỉ đạo tổ chức Kỳ thi tốt n...
# Processing document 30/500: Chỉ thị 15/CT-TTg tăng cường chỉ đạo, phối hợp tổ ...
# Processing document 31/500: Chỉ thị 21/CT-UBND về chỉ đạo, phối hợp tổ chức Kỳ...
# Processing document 32/500: Chỉ thị 5/CT-UBND tăng cường chỉ đạo, phối hợp tổ ...
# Processing document 33/500: Chỉ thị 7/CT-UBND về tăng cường công tác chỉ đạo, ...
# Processing document 34/500: Công điện 28/CĐ-TTg năm 2024 chấn chỉnh hoạt động ...
# Processing document 35/500: Công điện 60/CĐ-TTg tổ chức Kỳ thi tốt nghiệp trun...
# Processing document 36/500: Hướng dẫn 1908/HD-UBND về nội dung thực hiện Nghị ...
# Processing document 37/500: Hướng dẫn 2273/HD-UBND năm 2024 tổng kết công tác ...
# Processing document 38/500: Hướng dẫn 2346/HD-UBND năm 2024 thực hiện đánh giá...
# Processing document 39/500: Hướng dẫn 2347/HD-UBND năm 2024 thực hiện đánh giá...
# Processing document 40/500: Nghị quyết 01/2024/NQ-HĐND quy định mức học phí đố...
# Processing document 41/500: Nghị quyết 01/2024/NQ-HĐND quy định nội dung, mức ...
# Processing document 42/500: Nghị quyết 01/2024/NQ-HĐND về mức chi bảo đảm cho ...
# Processing document 43/500: Nghị quyết 01/2024/NQ-HĐND về mức thu học phí đối ...
# Processing document 44/500: Nghị quyết 01/2024/NQ-HĐND về Quy định mức học phí...
# Processing document 45/500: Nghị quyết 02/2024/NQ-HĐND quy định một số chính s...
# Processing document 46/500: Nghị quyết 02/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 47/500: Nghị quyết 02/2024/NQ-HĐND về Quy định mức thu học...
# Processing document 48/500: Nghị quyết 02/2024/NQ-HĐND về Quy định mức thu học...
# Processing document 49/500: Nghị quyết 03/2024/NQ-HĐND quy định chính sách miễ...
# Processing document 50/500: Nghị quyết 03/2024/NQ-HĐND quy định mức chi bảo đả...
# Processing document 51/500: Nghị quyết 03/2024/NQ-HĐND quy định về danh mục cá...
# Processing document 52/500: Nghị quyết 03/2024/NQ-HĐND quy định về mức chi bảo...
# Processing document 53/500: Nghị quyết 03/2024/NQ-HĐND quy định về mức học phí...
# Processing document 54/500: Nghị quyết 03/2024/NQ-HĐND sửa đổi Nghị quyết 13/2...
# Processing document 55/500: Nghị quyết 03/2024/NQ-HĐND sửa đổi Nghị quyết 44/2...
# Processing document 56/500: Nghị quyết 03/NQ-HĐND năm 2024 Danh mục dịch vụ sự...
# Processing document 57/500: Nghị quyết 04/2024/NQ-HĐND quy định hỗ trợ kinh ph...
# Processing document 58/500: Nghị quyết 04/2024/NQ-HĐND quy định mức học phí từ...
# Processing document 59/500: Nghị quyết 04/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 60/500: Nghị quyết 04/2024/NQ-HĐND quy định về mức thu học...
# Processing document 61/500: Nghị quyết 04/2024/NQ-HĐND sửa đổi Khoản 2 và bãi ...
# Processing document 62/500: Nghị quyết 04/2024/NQ-HĐND sửa đổi Nghị quyết 40/2...
# Processing document 63/500: Nghị quyết 05/2024/NQ-HĐND quy định hỗ trợ nhà giá...
# Processing document 64/500: Nghị quyết 05/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 65/500: Nghị quyết 05/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 66/500: Nghị quyết 05/2024/NQ-HĐND quy định nội dung, mức ...
# Processing document 67/500: Nghị quyết 05/2024/NQ-HĐND quy định nội dung, mức ...
# Processing document 68/500: Nghị quyết 05/2024/NQ-HĐND về Quy định mức thu học...
# Processing document 69/500: Nghị quyết 06/2024/NQ-HĐND quy định cơ chế thu và ...
# Processing document 70/500: Nghị quyết 06/2024/NQ-HĐND quy định Danh mục các k...
# Processing document 71/500: Nghị quyết 06/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 72/500: Nghị quyết 06/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 73/500: Nghị quyết 06/2024/NQ-HĐND quy định về chính sách ...
# Processing document 74/500: Nghị quyết 06/2024/NQ-HĐND quy định về mức thu học...
# Processing document 75/500: Nghị quyết 06/2024/NQ-HĐND về Quy định mức thu học...
# Processing document 76/500: Nghị quyết 07/2024/NQ-HĐND quy định chế độ hỗ trợ ...
# Processing document 77/500: Nghị quyết 07/2024/NQ-HĐND quy định học phí năm họ...
# Processing document 78/500: Nghị quyết 07/2024/NQ-HĐND quy định kinh phí hỗ tr...
# Processing document 79/500: Nghị quyết 07/2024/NQ-HĐND quy định mức chi bảo đả...
# Processing document 80/500: Nghị quyết 07/2024/NQ-HĐND quy định mức chi thực h...
# Processing document 81/500: Nghị quyết 07/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 82/500: Nghị quyết 07/2024/NQ-HĐND quy định về chính sách ...
# Processing document 83/500: Nghị quyết 07/2024/NQ-HĐND sửa đổi Phụ lục quy địn...
# Processing document 84/500: Nghị quyết 07/2024/NQ-HĐND về Quy định mức chi thự...
# Processing document 85/500: Nghị quyết 08/2024/NQ-HĐND kéo dài thời gian thực ...
# Processing document 86/500: Nghị quyết 08/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 87/500: Nghị quyết 08/2024/NQ-HĐND quy định nội dung và mứ...
# Processing document 88/500: Nghị quyết 08/2024/NQ-HĐND sửa đổi Quy định nội du...
# Processing document 89/500: Nghị quyết 09/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 90/500: Nghị quyết 09/2024/NQ-HĐND sửa đổi Nghị quyết 05/2...
# Processing document 91/500: Nghị quyết 101/NQ-HĐND năm 2024 đẩy mạnh thực hiện...
# Processing document 92/500: Nghị quyết 10/2024/NQ-HĐND quy định một số chính s...
# Processing document 93/500: Nghị quyết 10/2024/NQ-HĐND quy định mức chi cụ thể...
# Processing document 94/500: Nghị quyết 10/2024/NQ-HĐND quy định mức học phí đố...
# Processing document 95/500: Nghị quyết 10/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 96/500: Nghị quyết 10/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 97/500: Nghị quyết 10/2024/NQ-HĐND quy định về mức học phí...
# Processing document 98/500: Nghị quyết 10/2024/NQ-HĐND quy định về mức thu học...
# Processing document 99/500: Nghị quyết 10/2024/NQ-HĐND quy định về thu học phí...
# Processing document 100/500: Nghị quyết 10/2024/NQ-HĐND về Quy định chính sách ...
# Processing document 101/500: Nghị quyết 11/2024/NQ-HĐND quy định chính sách hỗ ...
# Processing document 102/500: Nghị quyết 11/2024/NQ-HĐND quy định mức chi đảm bả...
# Processing document 103/500: Nghị quyết 11/2024/NQ-HĐND về Quy định mức thu học...
# Processing document 104/500: Nghị quyết 11/2024/NQ-HĐND về Quy định nội dung, m...
# Processing document 105/500: Nghị quyết 12/2024/NQ-HĐND quy định mức chi thực h...
# Processing document 106/500: Nghị quyết 126/2024/NQ-HĐND quy định mức thu học p...
# Processing document 107/500: Nghị quyết 130/2024/NQ-HĐND quy định mức chi thực ...
# Processing document 108/500: Nghị quyết 13/2024/NQ-HĐND quy định mức chi bảo đả...
# Processing document 109/500: Nghị quyết 13/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 110/500: Nghị quyết 15/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 111/500: Nghị quyết 15/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 112/500: Nghị quyết 15/2024/NQ-HĐND về Quy định chính sách ...
# Processing document 113/500: Nghị quyết 16/2024/NQ-HĐND quy định mức học phí đố...
# Processing document 114/500: Nghị quyết 16/2024/NQ-HĐND quy định về nội dung, m...
# Processing document 115/500: Nghị quyết 16/2024/NQ-HĐND về Quy định nội dung ch...
# Processing document 116/500: Nghị quyết 16/NQ-HĐND năm 2024 phê duyệt tổng số l...
# Processing document 117/500: Nghị quyết 17/2024/NQ-HĐND quy định các khoản thu ...
# Processing document 118/500: Nghị quyết 17/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 119/500: Nghị quyết 21/2024/NQ-HĐND sửa đổi mức thu học phí...
# Processing document 120/500: Nghị quyết 22/2024/NQ-HĐND sửa đổi Phụ lục I kèm t...
# Processing document 121/500: Nghị quyết 25/2024/NQ-HĐND quy định đối tượng, mức...
# Processing document 122/500: Nghị quyết 308/2024/NQ-HĐND quy định mức chi bảo đ...
# Processing document 123/500: Nghị quyết 32/2024/NQ-HĐND sửa đổi Điểm c Khoản 1,...
# Processing document 124/500: Nghị quyết 32/NQ-CP năm 2024 Kế hoạch thực hiện Ng...
# Processing document 125/500: Nghị quyết 33/2024/NQ-HĐND quy định mức học phí gi...
# Processing document 126/500: Nghị quyết 34/NQ-HĐND năm 2024 sửa đổi Điều 1 Nghị...
# Processing document 127/500: Nghị quyết 35/2024/NQ-HĐND quy định biện pháp nâng...
# Processing document 128/500: Nghị quyết 36/NQ-CP năm 2024 phê duyệt Hiệp định g...
# Processing document 129/500: Nghị quyết 36/NQ-HĐND năm 2024 điều chỉnh Nghị quy...
# Processing document 130/500: Nghị quyết 373/2024/NQ-HĐND về Quy định nội dung, ...
# Processing document 131/500: Nghị quyết 374/2024/NQ-HĐND quy định về mức học ph...
# Processing document 132/500: Nghị quyết 38/2024/NQ-HĐND sửa đổi quy định tại Đi...
# Processing document 133/500: Nghị quyết 39/2024/NQ-HĐND quy định mức chi bảo đả...
# Processing document 134/500: Nghị quyết 393/2024/NQ-HĐND phê duyệt các khoản th...
# Processing document 135/500: Nghị quyết 394/2024/NQ-HĐND quy định mức học phí đ...
# Processing document 136/500: Nghị quyết 465/2024/NQ-HĐND quy định về mức thu họ...
# Processing document 137/500: Nghị quyết 49/2024/NQ-HĐND quy định mức thu học ph...
# Processing document 138/500: Nghị quyết 50/2024/NQ-HĐND hỗ trợ học phí đối với ...
# Processing document 139/500: Nghị quyết 55/2024/NQ-HĐND quy định mức hỗ trợ đối...
# Processing document 140/500: Nghị quyết 56/2024/NQ-HĐND quy định nội dung, mức ...
# Processing document 141/500: Nghị quyết 68/2024/NQ-HĐND sửa đổi Phụ lục I kèm t...
# Processing document 142/500: Nghị quyết 69/2024/NQ-HĐND sửa đổi Khoản 1 Điều 2 ...
# Processing document 143/500: Nghị quyết 69/2024/NQ-HĐND về Quy định nội dung, m...
# Processing document 144/500: Nghị quyết 74/2024/NQ-HĐND quy định về học phí từ ...
# Processing document 145/500: Nghị quyết 82/2024/NQ-HĐND quy định nội dung chi, ...
# Processing document 146/500: Nghị quyết 83/2024/NQ-HĐND quy định nội dung, mức ...
# Processing document 147/500: Nghị quyết 85/2024/NQ-HĐND quy định mức học phí đố...
# Processing document 148/500: Nghị quyết 89/2024/NQ-HĐND quy định về mức học phí...
# Processing document 149/500: Nghị định 35/2024/NĐ-CP quy định về xét tặng danh ...
# Processing document 150/500: Quyết định 01/2024/QĐ-UBND quy định về chức năng, ...
# Processing document 151/500: Quyết định 01/2024/QĐ-UBND quy định về chức năng, ...
# Processing document 152/500: Quyết định 02/2024/QĐ-UBND về danh mục ngành, nghề...
# Processing document 153/500: Quyết định 03/2024/QĐ-UBND quy định về chức năng, ...
# Processing document 154/500: Quyết định 03/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 155/500: Quyết định 04/2024/QĐ-UBND quy định chức năng, nhi...
# Processing document 156/500: Quyết định 04/2024/QĐ-UBND về Quy đinh chức năng, ...
# Processing document 157/500: Quyết định 05/2024/QĐ-UBND quy định chức năng, nhi...
# Processing document 158/500: Quyết định 05/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 159/500: Quyết định 06/2024/QĐ-TTg sửa đổi Quyết định 27/20...
# Processing document 160/500: Quyết định 06/2024/QĐ-UBND quy định về chức năng, ...
# Processing document 161/500: Quyết định 06/2024/QĐ-UBND quy định về Tiêu chí lự...
# Processing document 162/500: Quyết định 07/2024/QĐ-UBND quy định về chức năng, ...
# Processing document 163/500: Quyết định 07/2024/QĐ-UBND quy định về tiêu chí lự...
# Processing document 164/500: Quyết định 07/2024/QĐ-UBND quy định về tiêu chí, t...
# Processing document 165/500: Quyết định 07/2024/QĐ-UBND về Quy định danh mục ng...
# Processing document 166/500: Quyết định 07/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 167/500: Quyết định 07/2024/QĐ-UBND về tiêu chí lựa chọn sá...
# Processing document 168/500: Quyết định 08/2024/QĐ-UBND quy định về cơ chế thu ...
# Processing document 169/500: Quyết định 08/2024/QĐ-UBND quy định về tiêu chí lự...
# Processing document 170/500: Quyết định 08/2024/QĐ-UBND sửa đổi Khoản 1 và Khoả...
# Processing document 171/500: Quyết định 08/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 172/500: Quyết định 09/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 173/500: Quyết định 09/2024/QĐ-UBND về tiêu chí, tiêu chuẩn...
# Processing document 174/500: Quyết định 1001/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 175/500: Quyết định 1004/QĐ-BGDĐT năm 2024 về Tài liệu bài ...
# Processing document 176/500: Quyết định 1023/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 177/500: Quyết định 1023/QĐ-UBND năm 2024 về giá dịch vụ đà...
# Processing document 178/500: Quyết định 1030/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 179/500: Quyết định 1040/QĐ-SGDĐT năm 2024 về Nội quy bảo v...
# Processing document 180/500: Quyết định 1042/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 181/500: Quyết định 1044/QĐ-BGDĐT năm 2024 điều chỉnh liên ...
# Processing document 182/500: Quyết định 1055/QĐ-UBND năm 2024 phê duyệt Danh mụ...
# Processing document 183/500: Quyết định 1057/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 184/500: Quyết định 1064/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 185/500: Quyết định 1072/QĐ-UBND năm 2024 về phê duyệt Danh...
# Processing document 186/500: Quyết định 1079/QĐ-UBND năm 2024 phê duyệt bổ sung...
# Processing document 187/500: Quyết định 1093/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 188/500: Quyết định 1094/QĐ-BGDĐT năm 2024 Kế hoạch đánh gi...
# Processing document 189/500: Quyết định 1102/QĐ-UBND năm 2024 công bố danh mục ...
# Processing document 190/500: Quyết định 1109/QĐ-UBND năm 2024 phê duyệt 140 Dan...
# Processing document 191/500: Quyết định 1116/QĐ-UBND năm 2024 phê duyệt Danh mụ...
# Processing document 192/500: Quyết định 11/2024/QĐ-UBND phê duyệt Danh mục nghề...
# Processing document 193/500: Quyết định 11/2024/QĐ-UBND quy định cụ thể tiêu ch...
# Processing document 194/500: Quyết định 11/2024/QĐ-UBND quy định về tiêu chí lự...
# Processing document 195/500: Quyết định 11/2024/QĐ-UBND quy định định mức số lư...
# Processing document 196/500: Quyết định 11/2024/QĐ-UBND về Quy định cụ thể tiêu...
# Processing document 197/500: Quyết định 1122/QĐ-BGDĐT năm 2024 điều chỉnh liên ...
# Processing document 198/500: Quyết định 1128/QĐ-UBND năm 2024 phê duyệt Kế hoạc...
# Processing document 199/500: Quyết định 1136/QĐ-UBND năm 2024 công bố cắt giảm ...
# Processing document 200/500: Quyết định 1139/QĐ-BGDĐT Kế hoạch triển khai công ...
# Processing document 201/500: Quyết định 1142/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 202/500: Quyết định 1145/QĐ-UBND năm 2024 phê duyệt Danh mụ...
# Processing document 203/500: Quyết định 1154/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 204/500: Quyết định 1166/QĐ-UBND năm 2024 phê duyệt Danh mụ...
# Processing document 205/500: Quyết định 1167/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 206/500: Quyết định 1171/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 207/500: Quyết định 117/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 208/500: Quyết định 1187/QĐ-BGDĐT năm 2024 công bố thủ tục ...
# Processing document 209/500: Quyết định 1202/QĐ-BGDĐT năm 2024 phê duyệt Kế hoạ...
# Processing document 210/500: Quyết định 1215/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 211/500: Quyết định 12/2024/QĐ-UBND đơn giá dịch vụ sự nghi...
# Processing document 212/500: Quyết định 1220/QĐ-UBND năm 2024 phê duyệt quy trì...
# Processing document 213/500: Quyết định 1266/QĐ-BGDĐT phê duyệt Phương án tổ ch...
# Processing document 214/500: Quyết định 1270/QĐ-UBND năm 2024 về Quy chế đánh g...
# Processing document 215/500: Quyết định 1273/QĐ-UBND năm 2024 về phê duyệt 97 D...
# Processing document 216/500: Quyết định 1274/QĐ-UBND năm 2024 phê duyệt 42 Danh...
# Processing document 217/500: Quyết định 1277/QĐ-UBND năm 2024 phê duyệt Kế hoạc...
# Processing document 218/500: Quyết định 1287/QĐ-UBND năm 2024 về Kế hoạch thời ...
# Processing document 219/500: Quyết định 1293/QĐ-BGDĐT năm 2024 phê duyệt Tài li...
# Processing document 220/500: Quyết định 1299/QĐ-UBND năm 2024 về Kế hoạch thời ...
# Processing document 221/500: Quyết định 1302/QĐ-BGDĐT năm 2024 công bố thủ tục ...
# Processing document 222/500: Quyết định 1305/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 223/500: Quyết định 1310/QĐ-UBND phê duyệt Kế hoạch tổ chức...
# Processing document 224/500: Quyết định 1311/QĐ-UBND phê duyệt phương án tổ chứ...
# Processing document 225/500: Quyết định 1317/QĐ-UBND năm 2024 định mức số lượng...
# Processing document 226/500: Quyết định 13/2024/QĐ-UBND quy định về chức năng, ...
# Processing document 227/500: Quyết định 13/2024/QĐ-UBND quy định về tiêu chí lự...
# Processing document 228/500: Quyết định 1321/QĐ-UBND năm 2024 phê duyệt quy trì...
# Processing document 229/500: Quyết định 1338/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 230/500: Quyết định 1339/QĐ-UBND năm 2024 về Quy chế phối h...
# Processing document 231/500: Quyết định 1344/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 232/500: Quyết định 1370/QĐ-UBND năm 2024 về Kế hoạch thời ...
# Processing document 233/500: Quyết định 1373/QĐ-UBND năm 2024 phê duyệt danh mụ...
# Processing document 234/500: Quyết định 1384/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 235/500: Quyết định 1387/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 236/500: Quyết định 1388/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 237/500: Quyết định 1389/QĐ-UBND năm 2024 Kế hoạch tuyển si...
# Processing document 238/500: Quyết định 1390/QĐ-UBND năm 2024 Kế hoạch tổ chức ...
# Processing document 239/500: Quyết định 1399/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 240/500: Quyết định 139/QĐ-UBND năm 2024 sửa đổi quy định t...
# Processing document 241/500: Quyết định 1400/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 242/500: Quyết định 1419/QĐ-UBND năm 2024 về Kế hoạch thời ...
# Processing document 243/500: Quyết định 14/2024/QĐ-UBND quy định định mức kinh ...
# Processing document 244/500: Quyết định 1427/QĐ-UBND năm 2024 phê duyệt bổ sung...
# Processing document 245/500: Quyết định 1450/QĐ-BGDĐT năm 2024 đính chính Thông...
# Processing document 246/500: Quyết định 1465/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 247/500: Quyết định 1467/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 248/500: Quyết định 1471/QĐ-UBND năm 2024 phê duyệt bổ sung...
# Processing document 249/500: Quyết định 15/2024/QĐ-UBND bãi bỏ một phần Quyết đ...
# Processing document 250/500: Quyết định 15/2024/QĐ-UBND quy định cụ thể tiêu ch...
# Processing document 251/500: Quyết định 1521/QĐ-UBND năm 2024 phê duyệt Đề án N...
# Processing document 252/500: Quyết định 1539/QĐ-UBND năm 2024 phê duyệt quy trì...
# Processing document 253/500: Quyết định 1558/QĐ-BGDĐT năm 2024 công bố chỉ tiêu...
# Processing document 254/500: Quyết định 1558/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 255/500: Quyết định 1568/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 256/500: Quyết định 1569/QĐ-SGDĐT năm 2024 về điểm chuẩn tr...
# Processing document 257/500: Quyết định 1573/QĐ-SGDĐT năm 2024 về điểm chuẩn tr...
# Processing document 258/500: Quyết định 1596/QĐ-BGDĐT năm 2024 về Danh mục ngàn...
# Processing document 259/500: Quyết định 1598/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 260/500: Quyết định 1605/QĐ-CHK năm 2024 Kế hoạch hưởng ứng...
# Processing document 261/500: Quyết định 1605/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 262/500: Quyết định 1616/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 263/500: Quyết định 1617/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 264/500: Quyết định 1618/QĐ-BGDĐT năm 2024 phê duyệt liên k...
# Processing document 265/500: Quyết định 16/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 266/500: Quyết định 16/2024/QĐ-UBND về quy định tiêu chí lự...
# Processing document 267/500: Quyết định 16/2024/QĐ-UBND về Quy định định mức ki...
# Processing document 268/500: Quyết định 1622/QĐ-BCT điều chỉnh Kế hoạch phổ biế...
# Processing document 269/500: Quyết định 1627/QĐ-UBND năm 2024 về Khung kế hoạch...
# Processing document 270/500: Quyết định 1651/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 271/500: Quyết định 166/QĐ-UBND năm 2024 ​phê duyệt Kế hoạc...
# Processing document 272/500: Quyết định 1680/QĐ-BGDĐT năm 2024 điều chỉnh liên ...
# Processing document 273/500: Quyết định 1688/QĐ-UBND năm 2024 tiêu chí lựa chọn...
# Processing document 274/500: Quyết định 168/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 275/500: Quyết định 1692/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 276/500: Quyết định 1699/QĐ-BGDĐT năm 2024 phê duyệt Tài li...
# Processing document 277/500: Quyết định 169/QĐ-UBND năm 2024 phê duyệt điều chỉ...
# Processing document 278/500: Quyết định 1704/QĐ-UBND năm 2024 công bố Danh mục ...
# Processing document 279/500: Quyết định 1713/QĐ-UBND năm 2024 về danh mục thành...
# Processing document 280/500: Quyết định 1716/QĐ-BGDĐT năm 2024 về Tài liệu hướn...
# Processing document 281/500: Quyết định 17/2024/QĐ-UBND sửa đổi Quyết định 17/2...
# Processing document 282/500: Quyết định 17/2024/QĐ-UBND về Quy định chức năng, ...
# Processing document 283/500: Quyết định 17/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 284/500: Quyết định 17/2024/QĐ-UBND về Quy định vùng tạo ng...
# Processing document 285/500: Quyết định 1766/QĐ-BGDĐT năm 2024 công bố thủ tục ...
# Processing document 286/500: Quyết định 1774/QĐ-UBND năm 2024 phê duyệt danh mụ...
# Processing document 287/500: Quyết định 18/2024/QĐ-UBND quy định danh mục và th...
# Processing document 288/500: Quyết định 18/2024/QĐ-UBND quy định tiêu chuẩn, đị...
# Processing document 289/500: Quyết định 18/2024/QĐ-UBND thực hiện Nghị quyết 03...
# Processing document 290/500: Quyết định 1828/QĐ-UBND năm 2024 về Kế hoạch thời ...
# Processing document 291/500: Quyết định 1883/QĐ-BGDĐT năm 2024 điều chỉnh liên ...
# Processing document 292/500: Quyết định 1894/QĐ-UBND năm 2024 phê duyệt kế hoạc...
# Processing document 293/500: Quyết định 19/2024/QĐ-UBND về định mức kinh tế - k...
# Processing document 294/500: Quyết định 1957/QĐ-BGDĐT xác định ngưỡng đảm bảo c...
# Processing document 295/500: Quyết định 1962/QĐ-BVHTTDL năm 2024 về Kế hoạch tr...
# Processing document 296/500: Quyết định 196/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 297/500: Quyết định 1972/QĐ-UBND năm 2024 phê duyệt Danh mụ...
# Processing document 298/500: Quyết định 2012/QĐ-BGDĐT năm 2024 về Kế hoạch rà s...
# Processing document 299/500: Quyết định 20/2024/QĐ-UBND quy định chức năng, nhi...
# Processing document 300/500: Quyết định 20/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 301/500: Quyết định 2042/QĐ-UBND năm 2024 phê duyệt kế hoạc...
# Processing document 302/500: Quyết định 2045/QĐ-BGDĐT năm 2024 về Khung kế hoạc...
# Processing document 303/500: Quyết định 2045/QĐ-UBND năm 2024 phê duyệt quy trì...
# Processing document 304/500: Quyết định 2049/QĐ-UBND năm 2024 kế hoạch thực hiệ...
# Processing document 305/500: Quyết định 2060/QĐ-BGDĐT năm 2024 công bố danh mục...
# Processing document 306/500: Quyết định 214/QĐ-UBND năm 2024 quy định về tiêu c...
# Processing document 307/500: Quyết định 22/2024/QĐ-UBND quy định về chức năng, ...
# Processing document 308/500: Quyết định 22/2024/QĐ-UBND về Quy định chức năng, ...
# Processing document 309/500: Quyết định 222/QĐ-UBND năm 2024 quy định về tiêu c...
# Processing document 310/500: Quyết định 224/QĐ-UBND năm 2024 phê duyệt Đề án vị...
# Processing document 311/500: Quyết định 224/QĐ-UBND năm 2024 về Quy chế tổ chức...
# Processing document 312/500: Quyết định 228/QĐ-BLĐTBXH phê duyệt kế hoạch triển...
# Processing document 313/500: Quyết định 228/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 314/500: Quyết định 2312/QĐ-UBND năm 2024 điều chỉnh Kế hoạ...
# Processing document 315/500: Quyết định 23/2024/QĐ-UBND sửa đổi Điều 2 Quy định...
# Processing document 316/500: Quyết định 24/2024/QĐ-UBND bổ sung điểm 2.26a vào ...
# Processing document 317/500: Quyết định 2432/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 318/500: Quyết định 254/QĐ-UBND năm 2024 công bố Danh mục g...
# Processing document 319/500: Quyết định 2581/QĐ-UBND năm 2024 phê duyệt danh mụ...
# Processing document 320/500: Quyết định 265/QĐ-UBND năm 2024 quy định về tiêu c...
# Processing document 321/500: Quyết định 272/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 322/500: Quyết định 2733/QĐ-UBND năm 2024 quy định về chức ...
# Processing document 323/500: Quyết định 273/QĐ-UBND năm 2024 phê duyệt Đề án vị...
# Processing document 324/500: Quyết định 28/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 325/500: Quyết định 2826/QĐ-UBND năm 2024 về Khung kế hoạch...
# Processing document 326/500: Quyết định 2834/QĐ-UBND năm 2024 về Kế hoạch thời ...
# Processing document 327/500: Quyết định 284/QĐ-TTg năm 2024 chuyển đổi Trường Đ...
# Processing document 328/500: Quyết định 29/2024/QĐ-UBND thực hiện Nghị quyết 13...
# Processing document 329/500: Quyết định 29/2024/QĐ-UBND về Quy định tiêu chí lự...
# Processing document 330/500: Quyết định 29/2024/QĐ-UBND về tiêu chuẩn, định mức...
# Processing document 331/500: Quyết định 298/QĐ-TTg năm 2024 về Danh sách các đơ...
# Processing document 332/500: Quyết định 300/QĐ-TTg năm 2024 thành lập Hội đồng ...
# Processing document 333/500: Quyết định 303/QĐ-UBND năm 2024 phê duyệt vị trí v...
# Processing document 334/500: Quyết định 3048/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 335/500: Quyết định 3089/QĐ-UBND năm 2024 về Kế hoạch thời ...
# Processing document 336/500: Quyết định 311/QĐ-TCT năm 2024 Kế hoạch thực hiện ...
# Processing document 337/500: Quyết định 314/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 338/500: Quyết định 324/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 339/500: Quyết định 33/2024/QĐ-UBND về Quy định tiêu chí tu...
# Processing document 340/500: Quyết định 336/QĐ-UBND năm 2024 quy định về tiêu c...
# Processing document 341/500: Quyết định 348/QĐ-UBND năm 2024 phê duyệt quy trìn...
# Processing document 342/500: Quyết định 349/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 343/500: Quyết định 352/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 344/500: Quyết định 362/QĐ-UBND-HC năm 2024 công bố Danh mụ...
# Processing document 345/500: Quyết định 377/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 346/500: Quyết định 383/QĐ-UBND năm 2024 phê duyệt Điều lệ ...
# Processing document 347/500: Quyết định 392/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 348/500: Quyết định 394/QĐ-UBND năm 2024 công bố danh mục t...
# Processing document 349/500: Quyết định 395/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 350/500: Quyết định 396/QĐ-UBND năm 2024 công bố danh mục t...
# Processing document 351/500: Quyết định 406/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 352/500: Quyết định 409/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 353/500: Quyết định 409/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 354/500: Quyết định 416/QĐ-UBND năm 2024 phê duyệt chuẩn hó...
# Processing document 355/500: Quyết định 417/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 356/500: Quyết định 429/QĐ-UBND năm 2024 về Quy chế phối hợ...
# Processing document 357/500: Quyết định 431/QĐ-TTg giao kinh phí năm 2024 cho c...
# Processing document 358/500: Quyết định 433/QĐ-UBND năm 2024 công bố danh mục t...
# Processing document 359/500: Quyết định 437/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 360/500: Quyết định 449/QĐ-UBND năm 2024 công bố Quy trình ...
# Processing document 361/500: Quyết định 465/QĐ-UBND năm 2024 công bố danh mục v...
# Processing document 362/500: Quyết định 472/QĐ-TTg năm 2024 thành lập Trường Đạ...
# Processing document 363/500: Quyết định 4900/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 364/500: Quyết định 4903/QĐ-UBND năm 2024 công bố danh mục,...
# Processing document 365/500: Quyết định 497/QĐ-UBND về Kế hoạch nâng trình độ c...
# Processing document 366/500: Quyết định 50/2024/QĐ-UBND năm 2024 định mức kinh ...
# Processing document 367/500: Quyết định 511/QĐ-BTP Kế hoạch thực hiện công tác ...
# Processing document 368/500: Quyết định 513/QĐ-UBND năm 2024 quy định về tiêu c...
# Processing document 369/500: Quyết định 51/QĐ-TCGDNN năm 2024 về Quy chế đảm bả...
# Processing document 370/500: Quyết định 521/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 371/500: Quyết định 54/2024/QĐ-UBND về Quy định danh mục ti...
# Processing document 372/500: Quyết định 544/QĐ-UBND năm 2024 quy định Tiêu chí ...
# Processing document 373/500: Quyết định 555/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 374/500: Quyết định 556/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 375/500: Quyết định 558/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 376/500: Quyết định 563/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 377/500: Quyết định 565/QĐ-UBND năm 2024 về Tiêu chí lựa ch...
# Processing document 378/500: Quyết định 566/QĐ-UBND năm 2024 phê duyệt 04 Quy t...
# Processing document 379/500: Quyết định 567/QĐ-TTg năm 2024 phê duyệt Kế hoạch ...
# Processing document 380/500: Quyết định 569/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 381/500: Quyết định 570/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 382/500: Quyết định 571/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 383/500: Quyết định 577/QĐ-UBND năm 2024 công bố thủ tục hà...
# Processing document 384/500: Quyết định 5907/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 385/500: Quyết định 594/QĐ-UBND năm 2024 công bố Danh mục v...
# Processing document 386/500: Quyết định 596/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 387/500: Quyết định 6052/QĐ-UBND năm 2024 công bố thủ tục h...
# Processing document 388/500: Quyết định 608/QĐ-UBND năm 2024 phê duyệt kế hoạch...
# Processing document 389/500: Quyết định 610/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 390/500: Quyết định 610/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 391/500: Quyết định 611/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 392/500: Quyết định 622/QĐ-CT năm 2024 công bố thủ tục hành...
# Processing document 393/500: Quyết định 622/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 394/500: Quyết định 654/QĐ-UBND năm 2024 về Kế hoạch thời g...
# Processing document 395/500: Quyết định 656/QĐ-UBND năm 2024 phê duyệt quy trìn...
# Processing document 396/500: Quyết định 690/QĐ-UBND năm 2024 quy định về cơ cấu...
# Processing document 397/500: Quyết định 700/QĐ-UBND năm 2024 phê duyệt vị trí v...
# Processing document 398/500: Quyết định 712/QĐ-UBND phê duyệt Phương án tổ chức...
# Processing document 399/500: Quyết định 720/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 400/500: Quyết định 720/QĐ-UBND năm 2024 công bố thủ tục hà...
# Processing document 401/500: Quyết định 723/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 402/500: Quyết định 724/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 403/500: Quyết định 724/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 404/500: Quyết định 725/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 405/500: Quyết định 728/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 406/500: Quyết định 728/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 407/500: Quyết định 730/QĐ-UBND năm 2024 về thông qua chính...
# Processing document 408/500: Quyết định 731/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 409/500: Quyết định 732/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 410/500: Quyết định 733/QĐ-UBND năm 2024 danh mục vị trí vi...
# Processing document 411/500: Quyết định 734/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 412/500: Quyết định 734/QĐ-UBND năm 2024 phê duyệt quy trìn...
# Processing document 413/500: Quyết định 739/QĐ-UBND năm 2024 Định mức số lượng ...
# Processing document 414/500: Quyết định 741/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 415/500: Quyết định 742/QĐ-BGDĐT năm 2024 điều chỉnh liên k...
# Processing document 416/500: Quyết định 743/QĐ-UBND năm 2024 phê duyệt vị trí v...
# Processing document 417/500: Quyết định 749/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 418/500: Quyết định 753/QĐ-UBND năm 2024 phê duyệt chỉ tiêu...
# Processing document 419/500: Quyết định 754/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 420/500: Quyết định 758/QĐ-UBND năm 2024 công bố danh mục d...
# Processing document 421/500: Quyết định 758/QĐ-UBND năm 2024 về Tiêu chí lựa ch...
# Processing document 422/500: Quyết định 759/QĐ-BGDĐT năm 2024 phê duyệt liên kế...
# Processing document 423/500: Quyết định 760/QĐ-BGDĐT năm 2024 phê duyệt liên kế...
# Processing document 424/500: Quyết định 761/QĐ-BGDĐT năm 2024 Kế hoạch triển k...
# Processing document 425/500: Quyết định 764/QĐ-UBND phê duyệt Kế hoạch tổ chức ...
# Processing document 426/500: Quyết định 765/QĐ-UBND phê duyệt phương án tổ chức...
# Processing document 427/500: Quyết định 768/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 428/500: Quyết định 774/QĐ-UBND năm 2024 điều chỉnh sách gi...
# Processing document 429/500: Quyết định 776/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 430/500: Quyết định 777/QĐ-BGTVT điều chỉnh dự toán chi ngâ...
# Processing document 431/500: Quyết định 778/QĐ-UBND năm 2024 phê duyệt sách giá...
# Processing document 432/500: Quyết định 778/QĐ-UBND năm 2024 điều chỉnh Khung c...
# Processing document 433/500: Quyết định 783/QĐ-UBND năm 2024 phê duyệt sách giá...
# Processing document 434/500: Quyết định 784/QĐ-UBND năm 2024 phê duyệt sách giá...
# Processing document 435/500: Quyết định 785/QĐ-UBND năm 2024 công bố danh mục t...
# Processing document 436/500: Quyết định 790/QĐ-BGDĐT năm 2024 về Quy chế quản l...
# Processing document 437/500: Quyết định 791/QĐ-BGDĐT năm 2024 phê duyệt liên kế...
# Processing document 438/500: Quyết định 792/QĐ-UBND năm 2024 Danh mục thành phầ...
# Processing document 439/500: Quyết định 794/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 440/500: Quyết định 797/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 441/500: Quyết định 801/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 442/500: Quyết định 809/QĐ-BGDĐT công bố công khai dự toán ...
# Processing document 443/500: Quyết định 813/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 444/500: Quyết định 817/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 445/500: Quyết định 820/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 446/500: Quyết định 820/QĐ-UBND năm 2024 về Kế hoạch tuyển ...
# Processing document 447/500: Quyết định 824/QĐ-UBND năm 2024 công bố thủ tục hà...
# Processing document 448/500: Quyết định 836/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 449/500: Quyết định 848/QĐ-UBND năm 2024 về Quy định tiêu c...
# Processing document 450/500: Quyết định 849/QĐ-UBND năm 2024 công bố danh mục t...
# Processing document 451/500: Quyết định 850/QĐ-SGDĐT năm 2024 giao chỉ tiêu kế ...
# Processing document 452/500: Quyết định 850/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 453/500: Quyết định 853/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 454/500: Quyết định 853/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 455/500: Quyết định 854/QĐ-UBND năm 2024 công bố thủ tục hà...
# Processing document 456/500: Quyết định 871/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 457/500: Quyết định 884/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 458/500: Quyết định 885/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 459/500: Quyết định 898/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 460/500: Quyết định 899/QĐ-UBND năm 2024 phê duyệt quy trìn...
# Processing document 461/500: Quyết định 900/QĐ-BGDĐT năm 2024 phê duyệt danh mụ...
# Processing document 462/500: Quyết định 911/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 463/500: Quyết định 911/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 464/500: Quyết định 911/QĐ-UBND năm 2024 phê duyệt Kế hoạch...
# Processing document 465/500: Quyết định 922/QĐ-BLĐTBXH năm 2024 công bố thủ tục...
# Processing document 466/500: Quyết định 927/QĐ-UBND năm 2024 công bố Danh mục v...
# Processing document 467/500: Quyết định 928/QĐ-UBND năm 2024 thông qua chính sá...
# Processing document 468/500: Quyết định 944/QĐ-UBND năm 2024 về Kế hoạch thời g...
# Processing document 469/500: Quyết định 945/QĐ-UBND năm 2024 về Quy chế phối hợ...
# Processing document 470/500: Quyết định 962/QĐ-UBND năm 2024 phê duyệt 01 quy t...
# Processing document 471/500: Quyết định 967/QĐ-UBND năm 2024 thông qua chính sá...
# Processing document 472/500: Quyết định 977/QĐ-UBND năm 2024 phê duyệt danh mục...
# Processing document 473/500: Quyết định 980/QĐ-UBND năm 2024 đính chính Danh mụ...
# Processing document 474/500: Quyết định 989/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 475/500: Quyết định 990/QĐ-UBND năm 2024 phê duyệt Danh mục...
# Processing document 476/500: Quyết định 994/QĐ-UBND năm 2024 về Khung kế hoạch ...
# Processing document 477/500: Quyết định 995/QĐ-UBND năm 2024 công bố Danh mục t...
# Processing document 478/500: Quyết định 995/QĐ-UBND năm 2024 về các tiêu chí hư...
# Processing document 479/500: Quyết định số 308/QĐ-UBND năm 2024 phê duyệt vị tr...
# Processing document 480/500: Thông báo 3129/BNG-LPQT năm 2024 hiệu lực của Hiệp...
# Processing document 481/500: Thông tư 02/2024/TT-BGDĐT sửa đổi Quy chế thi tốt ...
# Processing document 482/500: Thông tư 03/2024/TT-BGDĐT về Hệ thống chỉ tiêu thố...
# Processing document 483/500: Thông tư 04/2024/TT-BGDĐT hướng dẫn về vị trí việ...
# Processing document 484/500: Thông tư 05/2024/TT-BGDĐT quy định về tiêu chuẩn, ...
# Processing document 485/500: Thông tư 05/2024/TT-BLĐTBXH quy định về chuẩn chuy...
# Processing document 486/500: Thông tư 06/2024/TT-BGDĐT về Quy chế Cuộc thi nghi...
# Processing document 487/500: Thông tư 08/2024/TT-BGDĐT hướng dẫn lồng ghép nội ...
# Processing document 488/500: Thông tư 09/2024/TT-BGDĐT quy định về công khai tr...
# Processing document 489/500: Thông tư 40/2024/TT-BTC hướng dẫn phương thức than...
# Processing document 490/500: Văn bản hợp nhất 01/VBHN-BGDĐT năm 2024 hợp nhất T...
# Processing document 491/500: Văn bản hợp nhất 02/VBHN-BGDĐT năm 2024 hợp nhất T...
# Processing document 492/500: Văn bản hợp nhất 03/VBHN-BGDĐT năm 2024 hợp nhất T...
# Processing document 493/500: Văn bản hợp nhất 04/VBHN-BGDĐT năm 2024 hợp nhất N...
# Processing document 494/500: Văn bản hợp nhất 05/VBHN-BGDĐT năm 2024 hợp nhất T...
# Processing document 495/500: Văn bản hợp nhất 06/VBHN-BGDĐT năm 2024 hợp nhất T...
# Processing document 496/500: Văn bản hợp nhất 1546/VBHN-BLĐTBXH năm 2024 hợp nh...
# Processing document 497/500: Văn bản hợp nhất 1548/VBHN-BLĐTBXH năm 2024 hợp nh...
# Processing document 498/500: Văn bản hợp nhất 1549/VBHN-BLĐTBXH năm 2024 hợp nh...
# Processing document 499/500: Văn bản hợp nhất 1550/VBHN-BLĐTBXH năm 2024 hợp nh...
# Processing document 500/500: Văn bản hợp nhất 2/VBHN-BNV hợp nhất Quyết định qu...
# [INFO] Created 16309 child chunks from 500 documents.
# [INFO] Parent chunks stored in docstore for context retrieval.
# [INFO] Chunk size statistics:
#    - Min tokens: 1
#    - Max tokens: 3372
#    - Avg tokens: 630
#    - Chunks over 3500 tokens: 0
# [SUCCESS] All chunks are within safe token limits.

# %% [markdown]
# # IV. Embedding Generation

# %%
# Enhanced Sentence-Transformers Embeddings with Token Limit Handling
from sentence_transformers import SentenceTransformer

class EnhancedSentenceTransformerEmbeddings(Embeddings):
    """
    Enhanced Sentence-Transformers embeddings class that handles token limit errors gracefully
    and provides dynamic batching with a progress bar.
    Features:
    - Uses a specified Sentence-Transformer model
    - Handles potential token limit issues (though Sentence-Transformers models have varying limits)
    - Dynamic, token-aware batching for efficient processing
    - Internal progress bar for user feedback
    """
    def __init__(self, model_name: str = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2', batch_size: int = 32):
        """Initializes the SentenceTransformer model and sets processing parameters."""
        # Using a multilingual model that generally performs well on various languages, including Vietnamese
        self.model = SentenceTransformer(model_name)
        self.batch_size = batch_size # Batch size for SentenceTransformer

        # Attempt to get max sequence length, default if not available
        try:
            self.max_seq_length = self.model.max_seq_length
        except AttributeError:
             # Default to a common max length if model doesn't expose it
            self.max_seq_length = 512
        print(f"Enhanced SentenceTransformerEmbeddings initialized with model '{model_name}'.")
        print(f"Max sequence length (approx): {self.max_seq_length}")


    def embed_documents(self, texts: List[str]) -> List[List[float]]:
        """
        Generates embeddings for a list of documents using dynamic batching and a progress bar.
        Sentence-Transformers handles token limits internally to some extent,
        but large documents might still be an issue depending on the model.
        We rely on the model's built-in batching and progress bar via encode().
        """
        # The SentenceTransformer.encode method handles batching and GPU usage internally
        # if a GPU is available. It also has a show_progress_bar argument.
        print(f"[INFO] Generating embeddings in batches of {self.batch_size}...")
        embeddings = self.model.encode(texts,
                                       batch_size=self.batch_size,
                                       show_progress_bar=True,
                                       convert_to_list=True)
        return embeddings

    def embed_query(self, text: str) -> List[float]:
        """Generates an embedding for a single query text."""
        # SentenceTransformer.encode can also handle single texts
        embedding = self.model.encode(text, convert_to_list=True)
        return embedding

print("Enhanced SentenceTransformerEmbeddings class created.")
print("Ready to use a Sentence-Transformer model for embeddings.")
# Out:
# Enhanced SentenceTransformerEmbeddings class created.
# Ready to use a Sentence-Transformer model for embeddings.

# %%
# 1. Initialize the enhanced embeddings class using Sentence-Transformers

# Use the new Sentence-Transformer embeddings class
# You can specify a different model name if needed
embeddings = EnhancedSentenceTransformerEmbeddings(model_name='sentence-transformers/paraphrase-multilingual-mpnet-base-v2')

print("Enhanced Sentence-Transformer embeddings object created and ready to use.")

# 2. Extract texts and metadatas from child chunks
texts = [chunk.page_content for chunk in child_chunks]
metadatas = [chunk.metadata for chunk in child_chunks]

# --- START OF PROCESS ---
print("\n" + "=" * 70)
print("   STARTING EMBEDDING GENERATION PROCESS (Sentence-Transformers)")
print("=" * 70)
print(f"[INFO] Number of text chunks to process: {len(texts)}")
print("-" * 70)

start_time = time.time()

# 3. Process all embeddings with a single call using the new class.
# The SentenceTransformer.encode method handles batching and progress.
text_embeddings = embeddings.embed_documents(texts)

end_time = time.time()
total_time = end_time - start_time

# --- FINAL SUMMARY REPORT ---
print("\n" + "=" * 70)
print("   EMBEDDING PROCESS COMPLETE: SUMMARY REPORT")
print("=" * 70)

# Check if text_embeddings is not empty and has the correct length
if len(text_embeddings) > 0 and len(text_embeddings) == len(texts):
    print(f"[SUCCESS] Process finished in {total_time:.2f} seconds ({total_time/60:.1f} minutes).")

    print("\n--- Performance Metrics ---")
    print(f"  -> {'Total chunks processed':<25}: {len(text_embeddings)}")
    # Calculate throughput based on actual successful embeddings
    if total_time > 0:
      print(f"  -> {'Throughput':<25}: {len(text_embeddings)/total_time:.1f} chunks/sec")
      print(f"  -> {'Avg. time per chunk':<25}: {(total_time/len(text_embeddings))*1000:.2f} ms")
    else:
        print("  -> Performance metrics not available (total time is zero).")


    print("\n--- Embedding Details ---")
    if len(text_embeddings) > 0:
        print(f"  -> {'Embedding dimension':<25}: {len(text_embeddings[0])}")
    else:
        print("  -> No embeddings were generated.")

else:
    print("[ERROR] Embedding generation failed or was incomplete. Please check the error logs above.")

print("=" * 70)
# Out:
# Enhanced SentenceTransformerEmbeddings initialized with model 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'.
# Max sequence length (approx): 128
# Enhanced Sentence-Transformer embeddings object created and ready to use.
#
# ======================================================================
#    STARTING EMBEDDING GENERATION PROCESS (Sentence-Transformers)
# ======================================================================
# [INFO] Number of text chunks to process: 16309
# ----------------------------------------------------------------------
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/510 [00:00<?, ?it/s]
# ======================================================================
#    EMBEDDING PROCESS COMPLETE: SUMMARY REPORT
# ======================================================================
# [SUCCESS] Process finished in 105.20 seconds (1.8 minutes).
#
# --- Performance Metrics ---
#   -> Total chunks processed   : 16309
#   -> Throughput               : 155.0 chunks/sec
#   -> Avg. time per chunk      : 6.45 ms
#
# --- Embedding Details ---
#   -> Embedding dimension      : 768
# ======================================================================

# %% [markdown]
# # V. Vector Store and Retriever Setup

# %%
# Setup FAISS vector store
print("\nCreating FAISS vector store...")
# FAISS requires (text, embedding) pairs
text_embedding_pairs = list(zip(texts, text_embeddings))
vectorstore_local = FAISS.from_embeddings(text_embedding_pairs, embeddings, metadatas=metadatas)
print("FAISS vector store created successfully.")

# Create and persist Qdrant vector store
print("\nCreating and persisting Qdrant vector store...")
from langchain_community.vectorstores import Qdrant
qdrant_store = Qdrant.from_documents(
    child_chunks,
    embeddings,
    location=":memory:",  # Use in-memory storage
    collection_name="vietjusticia_legal_docs",
)
print("Qdrant vector store created in-memory.")
print("Collection name: 'vietjusticia_legal_docs'")

# Setup BM25 retriever with Vietnamese tokenization
print("\nSetting up BM25 retriever with Vietnamese tokenization...")

def tokenize_vi_for_bm25(doc):
    """Tokenize Vietnamese text for better BM25 matching"""
    doc.page_content = ViTokenizer.tokenize(doc.page_content)
    return doc

# Create tokenized copies for BM25
child_chunks_tokenized = [tokenize_vi_for_bm25(chunk) for chunk in child_chunks]
bm25_retriever = BM25Retriever.from_documents(child_chunks_tokenized)
bm25_retriever.k = 15  # Retrieve top 15 for ensemble
print("BM25 retriever with Vietnamese tokenization created successfully.")
# Out:
# Creating FAISS vector store...
# FAISS vector store created successfully.
#
# Creating and persisting Qdrant vector store...
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Generating embeddings in batches of 32...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Qdrant vector store created in-memory.
# Collection name: 'vietjusticia_legal_docs'
#
# Setting up BM25 retriever with Vietnamese tokenization...
# BM25 retriever with Vietnamese tokenization created successfully.

# %%
# Setup Ensemble Retrieval (BM25 + Qdrant)
print("\nSetting up ensemble retrieval...")

# Create Qdrant retriever
qdrant_retriever = qdrant_store.as_retriever(search_kwargs={'k': 15})

# Create ensemble retriever combining BM25 and Qdrant
ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever, qdrant_retriever],
    weights=[0.6, 0.4]  # Favor BM25 for Vietnamese lexical matching
)

print("Ensemble retriever (BM25 + Qdrant) created successfully.")

# Setup Parent Document Retrieval Chain
def _get_parent_docs(input_dict: dict) -> list[Document]:
    """Retrieve parent documents from child documents"""
    child_docs = input_dict["child_docs"]
    store = input_dict["docstore"]
    parent_ids = []
    for doc in child_docs:
        if "parent_id" in doc.metadata and doc.metadata["parent_id"] not in parent_ids:
            parent_ids.append(doc.metadata["parent_id"])
    return [doc for doc in store.mget(parent_ids) if doc is not None]

# Create the parent retrieval chain
parent_retriever_chain = (
    {"child_docs": ensemble_retriever}
    | RunnablePassthrough.assign(docstore=lambda x: docstore)
    | RunnableLambda(_get_parent_docs)
)

print("Parent document retrieval chain created successfully.")
# Out:
# Setting up ensemble retrieval...
# Ensemble retriever (BM25 + Qdrant) created successfully.
# Parent document retrieval chain created successfully.

# %% [markdown]
# # VI. RAG Chain Setup and Testing

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-pro", temperature=0)

# Enhanced prompt template with Vietnamese instructions and citation requirements
template = """Answer the question based ONLY on the following context.
Your answer must be in Vietnamese.
Your answer should be well-structured and easy to read.
- Use bullet points or numbered lists for multiple items or steps.
- Use **bold** for key terms, names, or important numbers and concepts.
- Use *italics* for emphasis or to highlight specific terms.

**After providing the answer, you MUST cite your sources accurately using the metadata from the context.**
For each source used, provide its title and document number (Số hiệu) if available.

Context:
{context}

Question: {question}

If the context does not provide enough information, say "Tôi không tìm thấy thông tin trong tài liệu được cung cấp." and do not provide an answer."""

prompt = ChatPromptTemplate.from_template(template)

def format_docs(docs):
    """Format retrieved documents with metadata for better context"""
    formatted_docs = []
    for i, doc in enumerate(docs):
        # Add document metadata as header
        title = doc.metadata.get('title', f'Document {i+1}')
        source = doc.metadata.get('source', 'Unknown source')
        formatted_doc = f"--- Document: {title} ---\n{doc.page_content}\n--- End Document ---"
        formatted_docs.append(formatted_doc)
    return "\n\n".join(formatted_docs)

# Enhanced RAG chain using parent document retrieval
rag_chain = (
    {"context": parent_retriever_chain | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

print("Enhanced RAG chain with hybrid retrieval and parent documents created successfully.")
# Out:
# Enhanced RAG chain with hybrid retrieval and parent documents created successfully.

# %%
query = "thời gian học tập năm 2024-2025 tỉnh bắc kạn là từ khi nào?"
print(f"Query: {query}\n")
print("=" * 80)

response = rag_chain.invoke(query)
# print(f"Response: {response}\n")
display(Markdown(f"**Response:** {response}"))
# Out:
# Query: thời gian học tập năm 2024-2025 tỉnh bắc kạn là từ khi nào?
#
# ================================================================================
# **Response:** Dựa trên thông tin được cung cấp, kế hoạch thời gian năm học 2024-2025 đối với giáo dục mầm non, giáo dục phổ thông và giáo dục thường xuyên tại tỉnh Bắc Kạn như sau:
#
# *   **Ngày tựu trường**:
#     *   Các cấp học tựu trường sớm nhất vào **ngày 29 tháng 8 năm 2024** (Thứ Năm), trước 01 tuần so với ngày khai giảng.
#     *   Riêng đối với lớp 1, tựu trường sớm nhất vào **ngày 22 tháng 8 năm 2024** (Thứ Năm), trước 02 tuần so với ngày khai giảng.
# *   **Ngày khai giảng**: **Ngày 05 tháng 9 năm 2024** (Thứ Năm).
# *   **Thời gian học kỳ**:
#     *   Kết thúc học kỳ I: Trước **ngày 18 tháng 01 năm 2025**.
#     *   Hoàn thành chương trình và kết thúc năm học: Trước **ngày 31 tháng 5 năm 2025**.
# *   **Tổng thời gian thực học**: Kế hoạch năm học phải đảm bảo đủ **35 tuần** thực học, cụ thể:
#     *   Học kỳ I: **18 tuần**.
#     *   Học kỳ II: **17 tuần**.
#
# ***
#
# ### Nguồn tài liệu:
# *   **Tiêu đề**: Quyết định 1370/QĐ-UBND năm 2024 về Kế hoạch thời gian năm học 2024-2025 đối với giáo dục mầm non, giáo dục phổ thông và giáo dục thường xuyên tỉnh Bắc Kạn
# *   **Số hiệu**: 1370/QĐ-UBND

# %%
query = "Kỳ thi chọn học sinh giỏi cấp tỉnh lớp 12 được tổ chức vào ngày nào?"
print(f"Query: {query}\n")
print("=" * 80)

response = rag_chain.invoke(query)
# print(f"Response: {response}\n")
display(Markdown(f"**Response:** {response}"))
# Out:
# Query: Kỳ thi chọn học sinh giỏi cấp tỉnh lớp 12 được tổ chức vào ngày nào?
#
# ================================================================================
# **Response:** Dựa trên các văn bản được cung cấp, thời gian tổ chức **Kỳ thi chọn học sinh giỏi cấp tỉnh lớp 12** năm học 2024-2025 khác nhau tùy theo từng địa phương, cụ thể như sau:
#
# *   **Tỉnh Bình Định**: Tổ chức vào ngày **22/10/2024**.
# *   **Tỉnh Đắk Nông**: Tổ chức từ ngày **25 tháng 3 năm 2025** đến ngày **26 tháng 3 năm 2025**.
# *   **Tỉnh Lâm Đồng**: Hoàn thành tổ chức thi *trước ngày* **31/01/2025**.
# *   **Tỉnh Bắc Kạn**: Hoàn thành tổ chức thi *trước ngày* **28 tháng 4 năm 2025** (áp dụng cho cả cấp THCS và THPT).
# *   **Tỉnh Sóc Trăng**: Thời gian tổ chức *theo Kế hoạch của Sở Giáo dục và Đào tạo*.
#
# ***
#
# ### **Nguồn:**
# 1.  **Quyết định 2834/QĐ-UBND** năm 2024 về Kế hoạch thời gian năm học 2024-2025 đối với giáo dục mầm non, giáo dục phổ thông và giáo dục thường xuyên trên địa bàn tỉnh Bình Định.
# 2.  **Quyết định 944/QĐ-UBND** năm 2024 về Kế hoạch thời gian năm học 2024-2025 đối với giáo dục mầm non, giáo dục phổ thông và giáo dục thường xuyên do tỉnh Đắk Nông ban hành.
# 3.  **Quyết định 1287/QĐ-UBND** năm 2024 về Kế hoạch thời gian năm học 2024-2025 đối với giáo dục mầm non, giáo dục phổ thông và giáo dục thường xuyên trên địa bàn tỉnh Lâm Đồng.
# 4.  **Quyết định 1370/QĐ-UBND** năm 2024 về Kế hoạch thời gian năm học 2024-2025 đối với giáo dục mầm non, giáo dục phổ thông và giáo dục thường xuyên tỉnh Bắc Kạn.
# 5.  **Quyết định 1828/QĐ-UBND** năm 2024 về Kế hoạch thời gian năm học 2024-2025 đối với giáo dục mầm non, giáo dục phổ thông và giáo dục thường xuyên trên địa bàn tỉnh Sóc Trăng.

# %%
query = "Dựa trên hồ sơ do Công ty TNHH OTES CORPORATION cung cấp, hãy mô tả các đặc tính kỹ thuật chính của sản phẩm TamSoil Polynite ECO ở trạng thái dung dịch sau khi pha, và nêu rõ căn cứ pháp lý cao nhất (Luật) mà Cục Hải quan đã dựa vào để ban hành thông báo mã số cho sản phẩm này."
print(f"Query: {query}\n")
print("=" * 80)

response = rag_chain.invoke(query)
print(f"Response: {response}\n")

# Display with markdown formatting
display(Markdown(f"**Response:** {response}"))
# Out:
# Query: Dựa trên hồ sơ do Công ty TNHH OTES CORPORATION cung cấp, hãy mô tả các đặc tính kỹ thuật chính của sản phẩm TamSoil Polynite ECO ở trạng thái dung dịch sau khi pha, và nêu rõ căn cứ pháp lý cao nhất (Luật) mà Cục Hải quan đã dựa vào để ban hành thông báo mã số cho sản phẩm này.
#
# ================================================================================
# Response: Tôi không tìm thấy thông tin trong tài liệu được cung cấp.
# **Response:** Tôi không tìm thấy thông tin trong tài liệu được cung cấp.

# %% [markdown]
# # VII. Performance Comparison and Analysis
#
# ## Enhanced Features Summary
#
# ### ✅ **What's New in This Enhanced Version:**
#
# 1. **🔍 Hybrid Retrieval**: BM25 (lexical) + Qdrant (semantic) ensemble
# 2. **🇻🇳 Vietnamese Tokenization**: Better BM25 matching for Vietnamese text
# 3. **📚 Parent-Child Architecture**: Better context preservation
# 4. **📄 Enhanced Data Loading**: Preserves structured metadata
# 5. **🎯 Improved Prompting**: Vietnamese instructions with citation requirements
# 6. **⚡ Sentence-Transformers Embeddings**: High-quality multilingual embeddings
#
# ### **Architecture Flow:**
# ```
# Query → [BM25 + Qdrant] → Ensemble → Parent-Child Hydration → Enhanced RAG → Response
# ```
#
# ### **Key Improvements Over Original:**
# - **Better Recall**: Hybrid retrieval catches both exact matches and semantic similarity
# - **Better Context**: Parent-child architecture provides more complete context
# - **Vietnamese-Optimized**: Tokenization and multilingual embeddings
# - **Production-Ready**: Robust error handling and metadata preservation
# - **Citation Support**: Structured metadata for accurate source attribution
# - **Scalable Vector Store**: Qdrant provides better performance and scalability than FAISS
